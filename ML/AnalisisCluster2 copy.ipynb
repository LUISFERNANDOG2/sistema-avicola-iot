# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
os.chdir("./")

# %%
#obtener curret directory
os.getcwd()
# Out:
# 'h:\\My Drive\\Backup\\Documents\\Programming\\others\\Proyecto Avicola ML'

# %%
df=pd.read_csv('datos_pollitos.csv', sep=",")
df.head()
# Out:
#                    id_lectura  modulo                 hora  temperatura  \
# 0  2025-03-03T00:40:53.425_M1       1  2025-03-03 06:40:53         30.5
# 1  2025-03-03T00:40:55.428_M1       1  2025-03-03 06:40:55         30.5
# 2  2025-03-03T00:40:57.428_M1       1  2025-03-03 06:40:57         30.5
# 3  2025-03-03T00:48:09.847_M1       1  2025-03-03 06:48:09         30.9
# 4  2025-03-03T00:48:11.854_M1       1  2025-03-03 06:48:11         30.8
#
#    humedad  O2    CO   CO2   NH3
# 0       34 NaN  1611  1793  2478
# 1       33 NaN  1591  1313  2470
# 2       33 NaN  1603  1526  2498
# 3       37 NaN  1623  2185  2693
# 4       36 NaN  1621  2195  2663

# %%
df.tail()
# Out:
#                         id_lectura  modulo                 hora  temperatura  \
# 309776  2025-03-10T11:06:03.582_M1       1  2025-03-10 17:06:03         30.4
# 309777  2025-03-10T11:06:05.582_M1       1  2025-03-10 17:06:05         30.4
# 309778  2025-03-10T11:06:07.582_M1       1  2025-03-10 17:06:07         30.3
# 309779  2025-03-10T11:06:09.583_M1       1  2025-03-10 17:06:09         30.3
# 309780  2025-03-10T11:06:11.584_M1       1  2025-03-10 17:06:11         30.4
#
#         humedad  O2    CO   CO2   NH3
# 309776       46 NaN  1483  2737  2505
# 309777       46 NaN  1488  2702  2538
# 309778       45 NaN  1491  2702  2501
# 309779       45 NaN  1499  2667  2504
# 309780       45 NaN  1470  2667  2514

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309781 entries, 0 to 309780
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   id_lectura   309781 non-null  object
#  1   modulo       309781 non-null  int64
#  2   hora         309781 non-null  object
#  3   temperatura  309781 non-null  float64
#  4   humedad      309781 non-null  int64
#  5   O2           0 non-null       float64
#  6   CO           309781 non-null  int64
#  7   CO2          309781 non-null  int64
#  8   NH3          309781 non-null  int64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 21.3+ MB

# %%
fechas = []
for i in range(3,11):
    if i < 10:
        dia = "0"+str(i)
    else: dia = str(i)
    for h in range(0,23):
        if h < 10:
            hora = "0"+str(h)
        else: hora = str(h)
        diaHora = "2025-03-"+ dia + " " + hora + ":00:00"
        fechas.append(diaHora)

# %%
df_resumen = pd.DataFrame({'Fecha': fechas})
df_resumen['TemperaturaPromedioSensor'] = -1
df_resumen['HumedadPromedioSensor'] = -1

# %%
df_resumen.head(3)
# Out:
#                  Fecha  TemperaturaPromedioSensor  HumedadPromedioSensor
# 0  2025-03-03 00:00:00                         -1                     -1
# 1  2025-03-03 01:00:00                         -1                     -1
# 2  2025-03-03 02:00:00                         -1                     -1

# %%
df['hora'] = pd.to_datetime(df['hora'], infer_datetime_format=True)
df_resumen['Fecha'] = pd.to_datetime(df_resumen['Fecha'], infer_datetime_format=True)
# Out:
# C:\Users\luisf\AppData\Local\Temp\ipykernel_2708\3919533342.py:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df['hora'] = pd.to_datetime(df['hora'], infer_datetime_format=True)
# C:\Users\luisf\AppData\Local\Temp\ipykernel_2708\3919533342.py:2: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df_resumen['Fecha'] = pd.to_datetime(df_resumen['Fecha'], infer_datetime_format=True)

# %%
for index, row in df_resumen.iterrows():
    #print(row['FechaHoraManuals'])
    li = row['Fecha']
    ls = row['Fecha']+pd.to_timedelta(59, 'm')+pd.to_timedelta(59, 's')
    #print("Límite inferior: ",li)
    #print("Límite superior: ",ls)
    DateFiltered = df[(df['hora'] >= li) & (df['hora'] <= ls)]
    if len(DateFiltered) != 0:
       #print("Temperatura: ",DateFiltered['temperatura'].mean())
       df_resumen.iloc[index,1] = DateFiltered['temperatura'].mean()
       df_resumen.iloc[index,2] = DateFiltered['humedad'].mean()
# Out:
# C:\Users\luisf\AppData\Local\Temp\ipykernel_2708\3030014443.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '30.305027932960897' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_resumen.iloc[index,1] = DateFiltered['temperatura'].mean()
# C:\Users\luisf\AppData\Local\Temp\ipykernel_2708\3030014443.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '33.865921787709496' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_resumen.iloc[index,2] = DateFiltered['humedad'].mean()

# %%
df_resumen.tail()
# Out:
#                   Fecha  TemperaturaPromedioSensor  HumedadPromedioSensor
# 179 2025-03-10 18:00:00                       -1.0                   -1.0
# 180 2025-03-10 19:00:00                       -1.0                   -1.0
# 181 2025-03-10 20:00:00                       -1.0                   -1.0
# 182 2025-03-10 21:00:00                       -1.0                   -1.0
# 183 2025-03-10 22:00:00                       -1.0                   -1.0

# %%
#Eliminar -1
df_resumen.drop(df_resumen[df_resumen['TemperaturaPromedioSensor'] == -1].index,inplace=True)

# %%
df_resumen.head()
# Out:
#                  Fecha  TemperaturaPromedioSensor  HumedadPromedioSensor
# 6  2025-03-03 06:00:00                  30.305028              33.865922
# 7  2025-03-03 07:00:00                  31.472874              29.633685
# 8  2025-03-03 08:00:00                  31.360367              28.901612
# 9  2025-03-03 09:00:00                  30.199586              29.025641
# 10 2025-03-03 10:00:00                  29.147653              35.723005

# %%
df_resumen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 170 entries, 6 to 178
# Data columns (total 3 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Fecha                      170 non-null    datetime64[ns]
#  1   TemperaturaPromedioSensor  170 non-null    float64
#  2   HumedadPromedioSensor      170 non-null    float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 5.3 KB

# %%
x=df_resumen.iloc[:,[1,2]]
x.head()
# Out:
#     TemperaturaPromedioSensor  HumedadPromedioSensor
# 6                   30.305028              33.865922
# 7                   31.472874              29.633685
# 8                   31.360367              28.901612
# 9                   30.199586              29.025641
# 10                  29.147653              35.723005

# %%
x.corr()
# Out:
#                            TemperaturaPromedioSensor  HumedadPromedioSensor
# TemperaturaPromedioSensor                   1.000000              -0.526532
# HumedadPromedioSensor                      -0.526532               1.000000

# %%
final_df=x
final_df.head()
# Out:
#     TemperaturaPromedioSensor  HumedadPromedioSensor
# 6                   30.305028              33.865922
# 7                   31.472874              29.633685
# 8                   31.360367              28.901612
# 9                   30.199586              29.025641
# 10                  29.147653              35.723005

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=final_df, x='TemperaturaPromedioSensor')
# Out:
# <Axes: xlabel='TemperaturaPromedioSensor', ylabel='Count'>

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=final_df, x='HumedadPromedioSensor')
# Out:
# <Axes: xlabel='HumedadPromedioSensor', ylabel='Count'>

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
x_sc = StandardScaler() ## almacenamos la función en un objeto
X_sc=x_sc.fit_transform(final_df)## estandarizamos

# %%
import scipy.cluster.hierarchy as sch

# %%
X_sc #data escalada
# Out:
# array([[-8.84141001e-01, -9.68885494e-02],
#        [ 1.49619687e-01, -7.57118557e-01],
#        [ 5.00301251e-02, -8.71322198e-01],
#        [-9.77476326e-01, -8.51973638e-01],
#        [-1.90863332e+00,  1.92816879e-01],
#        [-3.16826933e+00,  1.70591416e-01],
#        [-2.28563788e+00,  2.72703196e-02],
#        [-1.87743746e+00, -1.82709337e-01],
#        [ 5.12084824e-01,  1.19339568e-01],
#        [ 7.20931152e-01, -8.82595147e-01],
#        [ 1.25361722e+00, -1.13406862e+00],
#        [ 1.78773021e+00, -1.25009327e+00],
#        [ 1.96781805e+00, -1.42551770e+00],
#        [ 2.57942786e+00, -1.40904185e+00],
#        [ 7.91342547e-01, -1.38311407e+00],
#        [ 5.27705752e-01, -1.32397444e+00],
#        [ 5.27705752e-01, -1.32397444e+00],
#        [ 5.27705752e-01, -1.32397444e+00],
#        [ 5.27705752e-01, -1.32397444e+00],
#        [ 5.27705752e-01, -1.32397444e+00],
#        [ 5.27705752e-01, -1.32397444e+00],
#        [ 5.27705752e-01, -1.32397444e+00],
#        [ 5.27705752e-01, -1.32397444e+00],
#        [ 5.27705752e-01, -1.32397444e+00],
#        [ 5.27705752e-01, -1.32397444e+00],
#        [ 5.27705752e-01, -1.32397444e+00],
#        [ 5.27705752e-01, -1.32397444e+00],
#        [ 5.27705752e-01, -1.32397444e+00],
#        [ 5.27705752e-01, -1.32397444e+00],
#        [ 5.27705752e-01, -1.32397444e+00],
#        [ 5.27705752e-01, -1.32397444e+00],
#        [ 5.58927232e-01, -1.11504396e+00],
#        [ 1.40560939e+00, -7.06303573e-01],
#        [ 2.04123091e+00, -9.20836457e-01],
#        [ 2.72654881e+00, -1.27099159e+00],
#        [ 2.81811806e+00, -1.24801211e+00],
#        [ 2.28976198e+00, -1.35588556e+00],
#        [ 1.52719560e-01, -1.42846601e+00],
#        [ 4.47601104e-01, -6.18548003e-01],
#        [ 5.03644835e-01, -2.08906392e-01],
#        [ 8.57276348e-01, -7.84870473e-02],
#        [ 2.67956098e-01,  3.04619777e-01],
#        [-1.97507369e-01,  3.51815085e-01],
#        [ 2.37400210e-01, -3.08805179e-02],
#        [ 4.56851518e-01,  9.66772320e-02],
#        [ 2.65397473e-01,  3.49361593e-02],
#        [ 2.48375086e-02,  9.65038020e-02],
#        [ 7.16601171e-01,  1.55643425e-01],
#        [ 8.58112821e-01,  3.13117846e-01],
#        [ 7.92425042e-01,  4.68771253e-01],
#        [ 6.31477682e-01,  5.41004839e-01],
#        [ 1.07357858e+00,  6.64140125e-01],
#        [ 9.81566483e-01,  7.55537724e-01],
#        [ 6.49142036e-01,  6.55295196e-01],
#        [ 5.79046533e-01,  5.93615498e-01],
#        [ 6.79304289e-01,  1.27027478e-01],
#        [ 1.29790342e-01, -3.53633710e-01],
#        [ 1.02531144e-01, -6.66588108e-01],
#        [ 1.27625352e-01, -7.26594880e-01],
#        [ 3.22425291e-01, -6.57222889e-01],
#        [-5.39536146e-01,  8.80924480e-02],
#        [-7.26364983e-01,  4.99468359e-01],
#        [-4.82801244e-02,  6.58416935e-01],
#        [ 6.14455294e-02,  7.51982409e-01],
#        [-3.63138626e-01,  5.38663535e-01],
#        [-4.60267972e-01,  5.01115944e-01],
#        [-8.41052223e-02,  7.71369135e-01],
#        [ 3.73991428e-01,  9.63740414e-01],
#        [ 8.70809848e-02,  1.02071216e+00],
#        [ 2.42962610e-02,  1.15676798e+00],
#        [-1.08457019e-01,  1.19813103e+00],
#        [-1.46245944e-01,  1.41665281e+00],
#        [-1.31730666e-01,  1.31025351e+00],
#        [ 1.12102198e-03,  1.28822791e+00],
#        [-2.41357912e-01,  1.19535615e+00],
#        [ 5.13190474e-01,  1.14020542e+00],
#        [ 6.81026441e-01,  9.46484131e-01],
#        [ 9.57308749e-01,  4.92444445e-01],
#        [ 7.63099262e-01, -8.15220719e-02],
#        [ 7.42335035e-01, -7.96140302e-01],
#        [ 1.26963905e+00, -1.06960734e+00],
#        [ 1.20987457e+00, -1.16381186e+00],
#        [-3.43604507e-01, -1.01318792e+00],
#        [-3.71158932e-01, -6.98846084e-01],
#        [-1.25481717e-01, -5.03737357e-01],
#        [ 5.13485700e-01, -3.91788305e-01],
#        [ 4.99265649e-01, -3.54067285e-01],
#        [-5.56607737e-02, -8.22157918e-02],
#        [ 4.64625802e-01,  2.37762520e-01],
#        [ 4.25213134e-01,  6.32142294e-01],
#        [ 2.36760554e-01,  6.35957753e-01],
#        [ 5.14961830e-01,  9.28273983e-01],
#        [ 5.60851045e-01,  1.12670308e+00],
#        [-2.03812698e-02,  1.32829023e+00],
#        [-3.08078982e-01,  1.14636218e+00],
#        [-1.23134901e+00,  7.60914053e-01],
#        [-1.39854532e+00,  7.29349797e-01],
#        [ 1.82242157e-01,  7.13307524e-01],
#        [ 1.60739865e-01,  6.01271757e-01],
#        [-6.56000482e-02,  1.57898015e-01],
#        [-5.38060016e-01, -4.24393141e-01],
#        [ 4.76214233e-03, -9.07742494e-01],
#        [ 5.82420965e-01, -1.27853579e+00],
#        [ 1.15717673e+00, -1.64776822e+00],
#        [ 1.34813873e+00, -1.87981753e+00],
#        [ 6.56352766e-01, -1.85116868e+00],
#        [-9.71796176e-01, -1.18618433e+00],
#        [-1.35603278e+00, -7.88335953e-01],
#        [-4.92939646e-01, -6.13084959e-01],
#        [-1.30549763e-01, -5.48742437e-01],
#        [-2.79540471e-01, -4.46765609e-01],
#        [ 2.38042177e-02,  1.27547768e-01],
#        [-5.77521888e-01,  3.50925582e-01],
#        [-6.51918833e-01,  3.02451903e-01],
#        [ 4.45878952e-01,  3.37137899e-01],
#        [ 2.91574176e-01,  3.40433068e-01],
#        [ 5.08073224e-01,  3.05920502e-01],
#        [ 4.14205251e-01,  3.62995104e-01],
#        [ 2.35776467e-01,  5.25482856e-01],
#        [ 1.84948395e-01,  6.64747130e-01],
#        [ 1.15029044e-01,  7.57272024e-01],
#        [ 4.31907233e-02,  5.22361117e-01],
#        [ 5.19490939e-02, -3.69505672e-02],
#        [-5.05585159e-01, -4.46505464e-01],
#        [-4.00435507e-01, -7.08818308e-01],
#        [ 2.52063100e-01, -9.36445156e-01],
#        [ 1.02958991e+00, -1.24870583e+00],
#        [ 1.26449137e+00, -1.49471626e+00],
#        [ 5.97920329e-01, -1.42517084e+00],
#        [-1.37812553e+00, -1.01769710e+00],
#        [-1.03113660e+00, -5.24375524e-01],
#        [-9.56050791e-01,  2.23367832e-01],
#        [-1.08053774e+00,  7.35679991e-01],
#        [-1.04604551e+00,  8.72516245e-01],
#        [-1.27917562e+00,  9.43795967e-01],
#        [-1.48529255e+00,  8.43380009e-01],
#        [-1.06287339e+00,  8.15804642e-01],
#        [-1.12245983e+00,  1.11705252e+00],
#        [-1.43382483e+00,  1.05921362e+00],
#        [-2.25268096e-01,  1.51429388e+00],
#        [-6.51229973e-01,  1.78076905e+00],
#        [-8.20776582e-01,  1.84023096e+00],
#        [-1.42427919e+00,  1.63014511e+00],
#        [-1.46369185e+00,  1.62554922e+00],
#        [-2.68813927e-01,  1.44223373e+00],
#        [ 3.17308041e-01,  8.11729037e-01],
#        [-6.46752379e-01, -7.55418566e-03],
#        [-4.07471727e-01, -3.84937821e-01],
#        [-2.79638880e-01, -7.25467586e-01],
#        [ 1.11594351e+00, -1.22113047e+00],
#        [ 1.77665924e+00, -1.61282208e+00],
#        [ 1.32968711e+00, -1.74454214e+00],
#        [-1.21345487e+00, -7.65789803e-02],
#        [-2.20234724e+00,  4.40849026e-01],
#        [-1.35819777e+00,  9.43015532e-01],
#        [-1.19985824e+00,  1.00388945e+00],
#        [-1.22273825e+00,  1.25718394e+00],
#        [-1.75739249e+00,  1.55903882e+00],
#        [-2.24038219e+00,  1.49339557e+00],
#        [-1.94333565e+00,  1.14905035e+00],
#        [-2.20805494e+00,  9.78915537e-01],
#        [-1.49596989e+00,  1.10040324e+00],
#        [-4.60071154e-01,  1.16648006e+00],
#        [-8.17491401e-01,  1.27747525e+00],
#        [-1.86652770e+00,  1.38474169e+00],
#        [-1.34593769e+00,  1.42431692e+00],
#        [-9.94873007e-01,  1.55088761e+00],
#        [ 2.01973093e-01,  1.65459874e+00],
#        [ 1.78010585e-01,  1.68035309e+00],
#        [-9.59977614e-01,  1.63164351e+00]])

# %%
from sklearn.metrics import euclidean_distances, silhouette_score

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
s = []

for n_clusters in range(2,10):
    hc = AgglomerativeClustering(n_clusters = n_clusters, 
                             linkage = 'ward')
    
    s.append(silhouette_score(X_sc, hc.fit_predict(X_sc)))#X_sc estandarizado

plt.plot(range(2, 10),s)
plt.ylabel("Silouette")
plt.xlabel("k")
plt.title("Silouette para data status")
# Out:
# Text(0.5, 1.0, 'Silouette para data status')

# %%
import scipy.cluster.hierarchy as sch

# %%
#definimos el dendograma, usaremos jerarquicos aglomerativos.
plt.figure(figsize=(12,6),dpi=500)
dendrogram = sch.dendrogram(sch.linkage(X_sc, metric = 'euclidean', method = 'ward')),#orientation='right') ## Usamos el método WARD para reducir la Var
plt.title('Dendrograma') ## asignamos nombre al título
plt.xlabel('Status')  ## asignamos nombre al eje x
plt.ylabel('Distancia Euclidea') ## asignamos nombre al eje y
plt.show() ## Visualizamos el plot

# %% [markdown]
# **Definamos el agrupamiento óptimo número final**

# %%
hc_final = AgglomerativeClustering(n_clusters = 6, 
                             linkage = 'ward')## realizamos la glusterización por ward, con 5 clusters
y_hc_final = hc_final.fit_predict(X_sc)## almacenamos en un objeto la clasificación de cada observación.

# %% [markdown]
# Veamos como quedaría los cluster de manera visual y veamos como estos se pueden describir.

# %%
df_resumen["Cluster"]=y_hc_final
df_resumen.head()
# Out:
#                  Fecha  TemperaturaPromedioSensor  HumedadPromedioSensor  \
# 6  2025-03-03 06:00:00                  30.305028              33.865922
# 7  2025-03-03 07:00:00                  31.472874              29.633685
# 8  2025-03-03 08:00:00                  31.360367              28.901612
# 9  2025-03-03 09:00:00                  30.199586              29.025641
# 10 2025-03-03 10:00:00                  29.147653              35.723005
#
#     Cluster
# 6         3
# 7         1
# 8         1
# 9         3
# 10        0

# %%
clust_map={
    0:"Cluster1",
    1:"Cluster2",
    2:"Cluster3",
    3:"Cluster4",
    4:"Cluster5",
    5:"Cluster6"
}
df_resumen.Cluster=df_resumen.Cluster.map(clust_map)

# %%
df_resumen.head()
# Out:
#                  Fecha  TemperaturaPromedioSensor  HumedadPromedioSensor  \
# 6  2025-03-03 06:00:00                  30.305028              33.865922
# 7  2025-03-03 07:00:00                  31.472874              29.633685
# 8  2025-03-03 08:00:00                  31.360367              28.901612
# 9  2025-03-03 09:00:00                  30.199586              29.025641
# 10 2025-03-03 10:00:00                  29.147653              35.723005
#
#      Cluster
# 6   Cluster4
# 7   Cluster2
# 8   Cluster2
# 9   Cluster4
# 10  Cluster1

# %%
df_resumen.groupby("Cluster").count()
# Out:
#           Fecha  TemperaturaPromedioSensor  HumedadPromedioSensor
# Cluster
# Cluster1     31                         31                     31
# Cluster2     48                         48                     48
# Cluster3     44                         44                     44
# Cluster4     25                         25                     25
# Cluster5      8                          8                      8
# Cluster6     14                         14                     14

# %%
cl_color={
    "Cluster1":"red",
    "Cluster2":"blue",
    "Cluster3":"green",
    "Cluster4":"cyan",
    "Cluster5":"magenta",
    "Cluster6":"black",    
}

# %%
#graficamos los clusters
fig,ax= plt.subplots()
for clust in clust_map.values():
    color=cl_color[clust]
    df_resumen[df_resumen.Cluster==clust].plot(kind="scatter",x="TemperaturaPromedioSensor",y="HumedadPromedioSensor",label=clust,ax=ax,color=color)
    handles,labels=ax.get_legend_handles_labels() #Mostrar las etiquetas en el diseño
    _=ax.legend(handles,labels,loc="upper right")

# %% [markdown]
# Mejorando el gráfico y su interpretación

# %% [markdown]
# ![ClusterRenombrado.png](attachment:611d961d-d4c8-4ced-b605-6c9dd7cbab82.png)

# %% [markdown]
# ![GraficoIntuitivo.png](attachment:2630e22b-ae9b-4374-b212-33315820e679.png)

# %% [markdown]
# Aquí el gráfico actualizado con los nombres de clústeres modificados según sus características de temperatura y humedad:
#
# Templado-Húmedo (rojo)
#
# Cálido-Seco (azul)
#
# Frío-Húmedo (verde)
#
# Templado (cian)
#
# Caluroso-Seco (magenta)

# %%
clust_map={
    "Cluster1":"Templado-Humedo",
    "Cluster2":"Calido-Seco",
    "Cluster3":"Frio-Humedo",
    "Cluster4":"Templado",
    "Cluster5":"Caluroso-Seco",
    "Cluster6":"Otro",
}
df_resumen.Cluster=df_resumen.Cluster.map(clust_map)

# %%
df_resumen.head()
# Out:
#                  Fecha  TemperaturaPromedioSensor  HumedadPromedioSensor  \
# 6  2025-03-03 06:00:00                  30.305028              33.865922
# 7  2025-03-03 07:00:00                  31.472874              29.633685
# 8  2025-03-03 08:00:00                  31.360367              28.901612
# 9  2025-03-03 09:00:00                  30.199586              29.025641
# 10 2025-03-03 10:00:00                  29.147653              35.723005
#
#             Cluster
# 6          Templado
# 7       Calido-Seco
# 8       Calido-Seco
# 9          Templado
# 10  Templado-Humedo

# %% [markdown]
# ### Data Set Ajustes (Captura Manual)

# %%
df = pd.read_excel("Ajustes310325.xlsx")

# %%
df["Ajuste Realizado"].value_counts()
# Out:
# Ajuste Realizado
# Sin Ajuste                                24
# Aumento de extractor                       6
# Reducción de extractor                     4
# Aumento de inlets o apertura de fondo      4
# Cambio a ciclos                            2
# Reducción de inlets o sellado de fondo     2
# Name: count, dtype: int64

# %%
df["Fecha"].value_counts()
# Out:
# Fecha
# 2025-03-12    7
# 2025-02-28    4
# 2025-03-05    4
# 2025-03-11    4
# 2025-03-17    4
# 2025-02-05    3
# 2025-02-18    2
# 2025-02-12    2
# 2025-02-11    2
# 2025-02-07    2
# 2025-02-02    2
# 2025-02-21    2
# 2025-03-01    2
# 2025-03-07    2
# Name: count, dtype: int64

# %%
df['Fecha'] = pd.to_datetime(df['Fecha'], infer_datetime_format=True)
# Out:
# C:\Users\luisf\AppData\Local\Temp\ipykernel_2708\3003646645.py:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df['Fecha'] = pd.to_datetime(df['Fecha'], infer_datetime_format=True)

# %%
df["Fecha"].value_counts()
# Out:
# Fecha
# 2025-03-12    7
# 2025-02-28    4
# 2025-03-05    4
# 2025-03-11    4
# 2025-03-17    4
# 2025-02-05    3
# 2025-02-18    2
# 2025-02-12    2
# 2025-02-11    2
# 2025-02-07    2
# 2025-02-02    2
# 2025-02-21    2
# 2025-03-01    2
# 2025-03-07    2
# Name: count, dtype: int64

# %%
x=df.iloc[:,[7,13]]
x.head()
# Out:
#    Temp IC (°C)-INIC  HR (%)-INIC
# 0               30.3         42.9
# 1               27.8         35.0
# 2               28.4         57.5
# 3               28.4         57.5
# 4               28.7         61.7

# %%
X_sc_=x_sc.fit_transform(x)## estandarizamos
X_sc_
# Out:
# array([[ 1.72753626, -0.89696772],
#        [ 0.81326556, -1.88440597],
#        [ 1.03269053,  0.92791816],
#        [ 1.03269053,  0.92791816],
#        [ 1.14240301,  1.45288534],
#        [ 0.15499065,  0.21546272],
#        [ 1.10583218, -0.97196303],
#        [ 2.02010289, -1.92190363],
#        [ 0.11841982, -1.72191613],
#        [ 0.22813231, -1.18444974],
#        [-0.1741468 , -1.14695209],
#        [-0.06443432, -0.55948882],
#        [-0.21071763,  0.11546897],
#        [-1.01527585,  1.64037361],
#        [-0.90556336,  1.86535954],
#        [ 0.15499065,  1.06540957],
#        [ 1.32525715, -0.29700524],
#        [-1.41755496, -0.05952009],
#        [-0.35700094,  1.50288221],
#        [-0.4301426 ,  0.44044865],
#        [-0.57642591,  0.76542833],
#        [ 1.39839881, -0.17201305],
#        [ 1.36182798, -0.10951696],
#        [-0.06443432, -1.27194427],
#        [ 0.33784479,  0.32795568],
#        [ 0.04527817,  0.37795256],
#        [ 0.11841982, -0.57198804],
#        [ 0.84983639,  0.69043302],
#        [ 0.44755728,  0.09047053],
#        [ 1.17897384,  0.02797444],
#        [ 0.77669473, -0.14701462],
#        [-0.57642591,  0.09047053],
#        [-0.53985508, -1.52192864],
#        [-0.75928005, -0.67198179],
#        [-1.01527585, -0.38449977],
#        [-1.71012158,  0.26545959],
#        [-0.64956757,  0.51544396],
#        [-0.72270922,  0.41545021],
#        [-1.01527585,  1.34039237],
#        [-1.30784247,  1.9028572 ],
#        [-1.8564049 , -0.67198179],
#        [-2.00268821, -0.79697397]])

# %%
y_hc_final_ = hc_final.fit_predict(X_sc_)

# %%
df["Cluster"]=y_hc_final_
df.head()
# Out:
#    consec      Fecha Granja Caseta  Edad              Sistema Original  \
# 0       1 2025-02-02   DAMS  Cta 1     8  Extractores solo temperatura
# 1       2 2025-02-02   DAMS  Cta 1     8          Mínima + temperatura
# 2       3 2025-02-05  GRQ 9  Cta 3    12              Solo temperatura
# 3       4 2025-02-05  GRQ 9  Cta 3    12              Solo temperatura
# 4       5 2025-02-05  GRQ 9  Cta 3    12       Después cambio a ciclos
#
#   Ajuste Realizado  Temp IC (°C)-INIC  Temp IC (°C)- FIN  Dif SP (°C)-INIC  \
# 0       Sin Ajuste               30.3               32.9               0.5
# 1       Sin Ajuste               27.8               29.5              -1.7
# 2  Cambio a ciclos               28.4               35.7               0.9
# 3  Cambio a ciclos               28.4               35.7               0.9
# 4       Sin Ajuste               28.7               31.5               1.2
#
#    ...  Temp BS (°C)-FIN  CO (ppm) MIN  CO (ppm) MAX  CO2 (ppm) MIN  \
# 0  ...              30.6             0             0           1136
# 1  ...              29.8             0             0            404
# 2  ...              30.1            14            32            400
# 3  ...              30.1            14            32            400
# 4  ...              28.9             2            18            400
#
#    CO2 (ppm) MAX  O2 (%) MIN  O2 (%) MAX  NH3 (ppm) MIN  NH3 (ppm) MAX  \
# 0           4572        19.5        20.9            0.0            0.0
# 1           2766        20.9        20.9            0.0            0.0
# 2           4446        19.3        20.9            0.0            0.0
# 3           4446        19.3        20.9            0.0            0.0
# 4           1995        20.9        20.9            0.0            0.0
#
#    Cluster
# 0        3
# 1        3
# 2        0
# 3        0
# 4        0
#
# [5 rows x 26 columns]

# %%
clust_map={
    0:"Templado-Humedo",
    1:"Calido-Seco",
    2:"Frio-Humedo",
    3:"Templado",
    4:"Caluroso-Seco",
    5:"Otro"
}
df.Cluster=df.Cluster.map(clust_map)

# %%
df.head(100)
# Out:
#     consec      Fecha  Granja  Caseta  Edad                Sistema Original  \
# 0        1 2025-02-02    DAMS   Cta 1     8    Extractores solo temperatura
# 1        2 2025-02-02    DAMS   Cta 1     8            Mínima + temperatura
# 2        3 2025-02-05   GRQ 9   Cta 3    12                Solo temperatura
# 3        4 2025-02-05   GRQ 9   Cta 3    12                Solo temperatura
# 4        5 2025-02-05   GRQ 9   Cta 3    12         Después cambio a ciclos
# 5        6 2025-02-07  DAMS 5   Cta 1    13                Solo temperatura
# 6        7 2025-02-07  DAMS 5   Cta 2    13            Ciclos + temperatura
# 7        8 2025-02-11   FML 3   Cta 4     6        Extractor túnel a 34.2°C
# 8        9 2025-02-11   FML 5   Cta 5     4               Extractores túnel
# 9       10 2025-02-12  DAMS 5   Cta 1    19                Solo temperatura
# 10      11 2025-02-12  DAMS 5   Cta 2    19            Ciclos + temperatura
# 11      12 2025-02-18  DAMS 2   Cta 3    18                Solo temperatura
# 12      13 2025-02-18  DAMS 2   Cta 4    18            Ciclos + temperatura
# 13      14 2025-02-21  DAMS 5   Cta 1    28                Solo temperatura
# 14      15 2025-02-21  DAMS 5   Cta 2    28            Ciclos + temperatura
# 15      16 2025-02-28  MEML 2   Cta 6     6      1 extractor, 22s (Gerente)
# 16      17 2025-02-28   PML 3   Cta 1     6                1 extractor, 47s
# 17      18 2025-02-28  GRQ 14   Cta 7    17             PE alta (0.09-0.11)
# 18      19 2025-02-28  GRQ 14   Cta 8    17             PE baja (0.04-0.06)
# 19      20 2025-03-01  GRQ 14   Cta 7    18    Cierre inlets últimos tramos
# 20      21 2025-03-01  GRQ 14   Cta 8    18              Sellado deficiente
# 21      22 2025-03-05   GRQ 4   Cta 3     8       3 extractores temperatura
# 22      23 2025-03-05   GRQ 4   Cta 2     8            Ciclos + temperatura
# 23      24 2025-03-05   GRQ 6   Cta 1    11                Solo temperatura
# 24      25 2025-03-05   GRQ 6   Cta 2    11            Ciclos + temperatura
# 25      26 2025-03-07   GRQ 8   Cta 1    18          Nivel 3, 4 extractores
# 26      27 2025-03-07   GRQ 8   Cta 2    18          Nivel 3, 4 extractores
# 27      28 2025-03-11  EPLT 8   Cta 5    11      1 extractor, 22s (Gerente)
# 28      29 2025-03-11  EPLT 8   Cta 6    10        3→2 extractores, 100→80s
# 29      30 2025-03-11  EPLT 9   Cta 2    11    2 extractores, 22s (Gerente)
# 30      31 2025-03-11  EPLT 9   Cta 1    11             3 extractores, 100s
# 31      32 2025-03-17  EPL 13   Cta 4    21       1 extractor mínima (124s)
# 32      33 2025-03-17  MEML 3   Cta 4    22       1 extractor mínima (115s)
# 33      34 2025-03-17   GRQ 6   Cta 1    23     PE 0.03-0.06, 3 ext. (136s)
# 34      35 2025-03-17   GRQ 6   Cta 2    23     PE 0.06-0.08, 3 ext. (136s)
# 35      36 2025-03-12  GRQ 14   Cta 7    37  4 extractores, inlets problema
# 36      37 2025-03-12  EPLT 8   Cta 5    24       3 extractores, inlets 30%
# 37      38 2025-03-12  EPLT 7  Cta 10    24       3 extractores, SP elevado
# 38      39 2025-03-12   GRQ 4   Cta 2    29   5 extractores por temperatura
# 39      40 2025-03-12   GRQ 6  Cta 10    29   6 extractores por temperatura
# 40      41 2025-03-12  GRQ 14   Cta 6    46     4 extractores (204s mínima)
# 41      42 2025-03-12  GRQ 15   Cta 2    44     4 extractores (198s mínima)
#
#                           Ajuste Realizado  Temp IC (°C)-INIC  \
# 0                               Sin Ajuste               30.3
# 1                               Sin Ajuste               27.8
# 2                          Cambio a ciclos               28.4
# 3                          Cambio a ciclos               28.4
# 4                               Sin Ajuste               28.7
# 5                               Sin Ajuste               26.0
# 6                               Sin Ajuste               28.6
# 7                               Sin Ajuste               31.1
# 8                     Aumento de extractor               25.9
# 9                               Sin Ajuste               26.2
# 10                              Sin Ajuste               25.1
# 11                              Sin Ajuste               25.4
# 12  Reducción de inlets o sellado de fondo               25.0
# 13                              Sin Ajuste               22.8
# 14                              Sin Ajuste               23.1
# 15                              Sin Ajuste               26.0
# 16   Aumento de inlets o apertura de fondo               29.2
# 17  Reducción de inlets o sellado de fondo               21.7
# 18                              Sin Ajuste               24.6
# 19                              Sin Ajuste               24.4
# 20                              Sin Ajuste               24.0
# 21                  Reducción de extractor               29.4
# 22                              Sin Ajuste               29.3
# 23                  Reducción de extractor               25.4
# 24                              Sin Ajuste               26.5
# 25   Aumento de inlets o apertura de fondo               25.7
# 26                              Sin Ajuste               25.9
# 27                              Sin Ajuste               27.9
# 28                  Reducción de extractor               26.8
# 29                              Sin Ajuste               28.8
# 30                  Reducción de extractor               27.7
# 31   Aumento de inlets o apertura de fondo               24.0
# 32                    Aumento de extractor               24.1
# 33                    Aumento de extractor               23.5
# 34                    Aumento de extractor               22.8
# 35                              Sin Ajuste               20.9
# 36   Aumento de inlets o apertura de fondo               23.8
# 37                    Aumento de extractor               23.6
# 38                    Aumento de extractor               22.8
# 39                              Sin Ajuste               22.0
# 40                              Sin Ajuste               20.5
# 41                              Sin Ajuste               20.1
#
#     Temp IC (°C)- FIN  Dif SP (°C)-INIC  ...  Temp BS (°C)-FIN  CO (ppm) MIN  \
# 0                32.9               0.5  ...              30.6             0
# 1                29.5              -1.7  ...              29.8             0
# 2                35.7               0.9  ...              30.1            14
# 3                35.7               0.9  ...              30.1            14
# 4                31.5               1.2  ...              28.9             2
# 5                32.4              -1.2  ...              29.6             0
# 6                31.8               0.7  ...              29.7             0
# 7                36.6               1.0  ...              33.8             0
# 8                31.1              -4.6  ...              30.7             0
# 9                28.5               0.7  ...              28.3             0
# 10               27.9              -0.4  ...              27.8             0
# 11               29.9              -0.4  ...              28.4             0
# 12               27.4              -0.8  ...              26.5             0
# 13               25.0              -0.2  ...              24.7             0
# 14               24.6               0.2  ...              24.2             0
# 15               30.6              -3.3  ...              28.6             0
# 16               32.0              -0.2  ...              30.3            22
# 17               27.2              -4.4  ...              26.6             0
# 18               28.8              -1.5  ...              26.7             0
# 19               26.1              -1.4  ...              25.6             0
# 20               29.1              -1.8  ...              26.8             5
# 21               33.0               0.7  ...              30.4            -1
# 22               30.8               0.7  ...              30.0            -1
# 23               29.1              -2.4  ...              28.3             4
# 24               30.7              -1.3  ...              29.1            10
# 25               26.6              -0.7  ...              27.1            37
# 26               29.2              -0.5  ...              27.7            17
# 27               33.4               0.1  ...              29.2             0
# 28               30.0              -1.3  ...              28.6             0
# 29               33.6               1.0  ...              29.2             0
# 30               30.1              -0.1  ...              28.6             0
# 31               25.9              -0.1  ...              25.7             0
# 32               28.3              -0.5  ...              28.5             0
# 33               24.7              -0.9  ...              24.8             0
# 34               24.8              -1.6  ...              24.9             0
# 35               23.9               0.5  ...              24.3             0
# 36               25.2              -0.3  ...              25.4             0
# 37               26.1              -0.5  ...              25.7             0
# 38               26.9               0.1  ...              25.8             0
# 39               24.7              -0.6  ...              24.2             0
# 40               22.1               1.5  ...              22.7             0
# 41               22.2               1.1  ...              22.8             0
#
#     CO (ppm) MAX  CO2 (ppm) MIN  CO2 (ppm) MAX  O2 (%) MIN  O2 (%) MAX  \
# 0              0           1136           4572       19.50        20.9
# 1              0            404           2766       20.90        20.9
# 2             32            400           4446       19.30        20.9
# 3             32            400           4446       19.30        20.9
# 4             18            400           1995       20.90        20.9
# 5              0            952           4590       20.50        20.9
# 6              0            920           1688       20.70        20.9
# 7              0            403            895       20.60        20.9
# 8              0            401            592       20.90        20.9
# 9              0            589           4560       19.40        20.9
# 10             0            400           2316       20.70        20.9
# 11             0            400            414       20.90        20.9
# 12             0            400           1494       20.70        20.9
# 13             0            401           4141       19.40        20.9
# 14             0            405           3686       20.90        20.9
# 15            66            402           4672       19.10        20.9
# 16            48            402           2197       20.30        20.9
# 17             0            403            414       20.90        20.9
# 18             0            403           1308       20.70        20.9
# 19             0            400           1887       20.70        20.9
# 20            11            403           1520       20.90        20.9
# 21            -1            403           1551       20.70        20.9
# 22            -1            401            759       20.90        20.9
# 23            20            538           1721       19.50        20.9
# 24            10            401            630       20.90        20.9
# 25            37            400           5675       19.30        20.9
# 26            17            401            428       19.90        20.9
# 27             0           4300           4666       19.00        19.5
# 28             0            401           1383       20.90        20.9
# 29             0            400           3856       19.10        20.9
# 30             0            401           1771       20.90        20.9
# 31             0            402           1206       19.40        20.9
# 32             0             -1             -1       20.90        20.9
# 33             0            401           2395       19.90        20.9
# 34             0            411           1063       20.60        20.9
# 35             0            404            945       20.90        20.9
# 36             0            405           1335       20.90        20.9
# 37             0            400           1470       20.90        20.9
# 38             0            400           1019       20.06        20.9
# 39             0            400           1001       20.40        20.9
# 40             0            410           1755       19.80        20.9
# 41             0            408            861       20.90        20.9
#
#     NH3 (ppm) MIN  NH3 (ppm) MAX          Cluster
# 0             0.0            0.0         Templado
# 1             0.0            0.0         Templado
# 2             0.0            0.0  Templado-Humedo
# 3             0.0            0.0  Templado-Humedo
# 4             0.0            0.0  Templado-Humedo
# 5             0.0            0.0      Calido-Seco
# 6             0.0            0.0         Templado
# 7             0.0            0.0         Templado
# 8             0.0            0.0      Frio-Humedo
# 9             0.0            0.0      Frio-Humedo
# 10            0.0            0.0      Frio-Humedo
# 11            0.0            3.6      Frio-Humedo
# 12            0.0            1.5      Calido-Seco
# 13            0.0            4.9             Otro
# 14            0.0            4.2             Otro
# 15            0.0            0.0             Otro
# 16            0.0            0.0  Templado-Humedo
# 17            0.0            0.0    Caluroso-Seco
# 18            0.0            0.0             Otro
# 19            0.0            0.0      Calido-Seco
# 20            0.0            0.0      Calido-Seco
# 21            0.0            0.0  Templado-Humedo
# 22            0.0            0.0  Templado-Humedo
# 23            0.0            0.0      Frio-Humedo
# 24            0.0            0.0      Calido-Seco
# 25            0.0            0.0      Calido-Seco
# 26            0.0            0.0      Frio-Humedo
# 27            0.0            0.0  Templado-Humedo
# 28            0.0            0.0      Calido-Seco
# 29            0.0            0.0  Templado-Humedo
# 30            0.0            0.0  Templado-Humedo
# 31            0.0            0.0      Calido-Seco
# 32            0.0            0.0      Frio-Humedo
# 33            0.0            0.0      Frio-Humedo
# 34            0.0            0.0      Frio-Humedo
# 35            0.0            0.9    Caluroso-Seco
# 36            0.0            0.0      Calido-Seco
# 37            0.0            2.4      Calido-Seco
# 38            0.0            0.0             Otro
# 39            0.0            0.0             Otro
# 40            0.2            2.3    Caluroso-Seco
# 41            0.0            0.6    Caluroso-Seco
#
# [42 rows x 26 columns]

# %%
# Exportar resultados con clústeres
df_resultados = df_resumen[['Fecha', 'TemperaturaPromedioSensor', 'HumedadPromedioSensor', 'Cluster']].copy()

# También en CSV
df_resultados.to_csv('Resultados_Clusters_Avicola.csv', index=False)

# %%
print(f"Se exportaron {len(df_resultados)} registros")
print("Archivos creados:")
print("- Resultados_Clusters_Avicola.xlsx")
print("- Resultados_Clusters_Avicola.csv")

# Mostrar resumen
print("\nResumen de clústeres:")
print(df_resultados['Cluster'].value_counts())
# Out:
# Se exportaron 170 registros
# Archivos creados:
# - Resultados_Clusters_Avicola.xlsx
# - Resultados_Clusters_Avicola.csv
#
# Resumen de clústeres:
# Cluster
# Calido-Seco        48
# Frio-Humedo        44
# Templado-Humedo    31
# Templado           25
# Otro               14
# Caluroso-Seco       8
# Name: count, dtype: int64

# %%
# Características temporales
df['hora'] = df['Fecha'].dt.hour
df['dia_semana'] = df['Fecha'].dt.dayofweek  
df['mes'] = df['Fecha'].dt.month
df['cluster_num'] = df['Cluster'].astype('category').cat.codes

# Variables para modelos
features = ['TemperaturaPromedioSensor', 'HumedadPromedioSensor', 'hora', 'dia_semana']
target = 'cluster_num'  # o temperatura/humedad directamente
